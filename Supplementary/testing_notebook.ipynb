# %% [markdown]
# Example: call the `testing` function from `utils.py` (in `Labs/Lab Utils`). Since we're working in a notebook, we'll add the relative path to the path.

# %%
import sys
sys.path.append('../Labs/Lab Utils') # add the path to the utils.py file

# %% [markdown]
# Now we can import and call our function in one of two ways.

# %%
# #1
from utils import testing
testing()
# Out:
# This is a test function. Let's see if the updates stick!

# %%
# #2
import utils
utils.testing()
# Out:
# This is a test function. Let's see if the updates stick!
